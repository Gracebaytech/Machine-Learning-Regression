# %% [markdown]
# #  Solve the problem
#
# ## Introduction
#
# What is a Regression Problem? A Regression Problem is when an output/target variable is real or continuous value. Regression is supervised machine learning technique which is used in prediction of these continuous variables such as height, salary & house price😉 too.
#
# So what exactly we are trying to do? We are trying to : Predict a Target Using some features
#
# Now let's come to the competion problem statement
#
#
# ## Challenge Objectives
# In context of the details shared above via the Project Background, in this challenge we are looking to introduce a straightforward regression practice problem.
#
# The dataset has been shared in the challenge forum. There are 45 features in the dataset, and one regression label (i.e. it's a single-label prediction challenge, not multi-label)
#
# Within this goal the following are the targets:
#
# Train a model, using the file train.csv - The train.csv file can be found in the challenge dataset folder in the forum. That file should be used to train a machine learning model. Here the last (right-most) column in the file is the label, and all other columns are features
# Using the trained model, predict regression labels for test_x.csv - The test_x.csv file contains the test dataset. It does NOT contain the labels, and hence the regression labels need to be predicted.

# %% [markdown]
# ## Importing necessary libraries📚

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
np.random.seed(123)
warnings.filterwarnings('ignore')
# %matplotlib inline

# %% [markdown]
# ## Load the train and test dataset.

# %%
# Read training and testing csv file
# Let's see what's inside🧐

# Import data
train = pd.read_csv('train.csv',header=None)
test = pd.read_csv('test_x.csv',header=None)

# %% [markdown]
# ## Let’s observe the shape of our datasets.

# %%
# print shape
print('train data shape :', train.shape)
print('test data shape :', test.shape)
# Out:
# train data shape : (14700, 46)
# test data shape : (6300, 45)

# %% [raw]
# The above output shows the number of rows and columns for train and test dataset. We have 46 variables in the train dataset, 145 independent variables and 1 dependent variable. In the test dataset, we have 45 independent variables.
#
# We can observe the first five rows from our data set by using the head() method from the pandas library.

# %%
# inspect train data
train.head()
# Out:
#             0            1            2            3            4   \
# 0 -4660.197737  2665.495526 -1104.915343   563.350855     6.945110
# 1  5290.777109 -8871.620989  2040.742184  1941.290147  -278.315345
# 2 -5079.817347   246.732978   -82.682441   358.441882   639.135525
# 3 -3179.838400   129.635078  1198.864399  -404.091302  1017.011710
# 4  8031.785309 -3133.016055 -1792.306828  1043.586308  -304.023415
#
#            5           6           7           8           9   ...        36  \
# 0  273.731752  257.039238 -127.932947   37.314456  -46.378287  ...  2.103955
# 1    8.565463  -17.412734  348.533407  371.050559   58.740439  ...  2.858535
# 2   52.071644  562.167586 -281.638695   78.059886   18.453052  ... -7.614588
# 3  396.553775 -326.369718  604.641433  -28.455874 -178.166313  ...  0.181635
# 4 -216.729002  250.475959  139.402207 -118.387878   86.607414  ... -4.013917
#
#          37        38        39        40        41        42        43  \
# ...

# %%
# inspect test dataset

test.head()
# Out:
#             0             1            2            3           4   \
# 0  2515.936305   7288.285512 -1858.830138   222.574033 -916.797456
# 1  2454.139714    103.556679  -598.520955   462.366973 -335.328987
# 2  5609.467216   2157.838672 -2314.190682  -170.946082   13.434814
# 3  3664.016902 -10135.360948 -2513.506198 -1210.826651  370.625464
# 4 -4537.429816     61.474415  -586.041802   633.223813  736.243819
#
#             5           6           7           8           9   ...        35  \
# 0 -1047.550169 -127.957684  195.880387  -60.634930  273.436423  ... -3.122042
# 1 -1095.038558  -85.263061  100.783570  -92.923532   13.724276  ...  5.194352
# 2 -1000.952134 -377.684223  230.026122  127.914059   50.447168  ...  2.394519
# 3   339.078681  105.921730  203.945078  449.974420   45.771650  ... -5.844049
# 4   -55.852641 -208.141954 -207.778268   93.310093   51.814536  ...  0.219893
#
#          36        37        38        39        40        41        42  \
# ...

# %%
train.dtypes
# Out:
# 0     float64
# 1     float64
# 2     float64
# 3     float64
# 4     float64
# 5     float64
# 6     float64
# 7     float64
# 8     float64
# 9     float64
# 10    float64
# 11    float64
# 12    float64
# 13    float64
# 14    float64
# 15    float64
# 16    float64
# 17    float64
# 18    float64
# 19    float64
# 20    float64
# 21    float64
# 22    float64
# 23    float64
# 24    float64
# 25    float64
# 26    float64
# 27    float64
# 28    float64
# 29    float64
# 30    float64
# 31    float64
# 32    float64
# 33    float64
# 34    float64
# 35    float64
# 36    float64
# 37    float64
# 38    float64
# 39    float64
# 40    float64
# 41    float64
# 42    float64
# 43    float64
# 44    float64
# 45    float64
# dtype: object

# %% [markdown]
# ### Examine Missing Values

# %%
train.isnull().sum().sum()
# Out:
# 0

# %%
test.isnull().sum().sum()
# Out:
# 0

# %% [raw]
# The output shows the list of variables/features, sizes, if it contains missing values and data type for each variable. From the dataset, we don’t have any missing values and we have 46 features of float data type

# %%
train.describe().T
# Out:
#       count       mean          std           min          25%          50%  \
# 0   14700.0  -2.928685  6872.953260  -8068.771503 -4767.271846 -3451.622656
# 1   14700.0 -17.518314  4784.468064 -11211.410660 -2275.025951     3.888990
# 2   14700.0  11.459230  1933.993280 -10205.002558  -755.818656    -8.958387
# 3   14700.0  -8.162813   890.619064  -3684.714678  -596.777993    74.874144
# 4   14700.0   0.655671   811.539319  -4534.040750  -547.710341    93.983217
# 5   14700.0  -4.043439   633.328574  -2305.025359  -271.734816   -83.399018
# 6   14700.0  -0.138544   336.898341  -1730.204557  -179.435951    -2.845638
# 7   14700.0  -0.006607   245.082789  -1566.521099  -150.598860   -47.721963
# 8   14700.0   0.066400   182.482671   -783.203839   -79.440460     6.842191
# 9   14700.0   0.556442   126.622677   -505.731353   -72.675584    -7.721030
# 10  14700.0  -0.340992   107.529987   -482.940947   -52.271028    -0.030772
# ...

# %% [markdown]
# # Model Development

# %% [markdown]
# This section includes below steps:
#
# Data preparation in order to feed the model
#
# Develop different models and compare them.

# %%
# importing python libaries

import time
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import SGDRegressor
from sklearn.svm import SVR
from  sklearn.linear_model import BayesianRidge
from catboost import CatBoostRegressor
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import LinearRegression
from xgboost.sklearn import XGBRegressor
from lightgbm import  LGBMRegressor


from sklearn.metrics import mean_absolute_error, mean_squared_error,mean_absolute_error,r2_score,accuracy_score
from sklearn.model_selection import train_test_split

# %%
# splitting dataset in train abf val
X=train.iloc[:,0: -1]
Y = train.iloc[:, -1]
test_size=0.20
seed=42
X_train, X_Val, Y_train, Y_Val = train_test_split(X, Y, test_size=test_size,random_state=seed)

# %%
def Models(model, name, d):
    print("Working on {} model".format(name))
    
    
    cla = model
    cla.fit(X_train, Y_train)
    
   
    
    predicted = cla.predict(X_Val)
   
    
    MAE=mean_absolute_error(Y_Val,predicted)
    MSE=mean_squared_error(Y_Val,predicted)
    RMSE=mean_squared_error(Y_Val,predicted,squared=False)
    MAEA=mean_absolute_error(Y_Val,predicted)
    R2=r2_score(Y_Val,predicted)
    
    
    
    d['Name'].append(name)
    #d['Training ACU'].append(tr_auc)
    #d['Testing ACU'].append(te_auc)
    d["RMSE"].append(RMSE)
    d['MAE'].append(MAE)
    d['MSE'].append(MSE)
    d['MAEA'].append(MAEA)
    d['R2'].append(R2)
    
    
    
    
    print("**********"*5)
    print()
    return d

# %%
d = {'Name' : [], 'RMSE': [], 'R2': [], 'MAE': [], 'MSE': [],'MAEA': []}


models = [ [GradientBoostingRegressor(loss="squared_error",learning_rate=0.2,n_estimators=1000), 'GradientBoostRegressor'],
          [ElasticNet(max_iter=2000,normalize=True), 'ElasticNet'], 
          [LGBMRegressor(), 'LightGBM'],
          [SGDRegressor(l1_ratio=0.5,), "SGDRegressor"],

          [CatBoostRegressor(), 'CatBoost'], 
          [KernelRidge(alpha=1.0), 'kernal Ridge'],
          [LinearRegression(), 'Linear Regression'], 
          [SVR(C=1.0,epsilon=0.2), 'Support Vector Ratio' ],
         [XGBRegressor(objective="reg:linear"),"XGBRegressor"],
         [BayesianRidge(),"BayesianRidge"]
         ]




for model in models:
    d = Models(model[0], model[1], d)

acu_data = pd.DataFrame(data = d)
# Out:
# Working on GradientBoostRegressor model
# **************************************************
#
# Working on ElasticNet model
# **************************************************
#
# Working on LightGBM model
# **************************************************
#
# Working on SGDRegressor model
# **************************************************
#
# Working on CatBoost model
# Learning rate set to 0.060437
# 0:	learn: 32.9024384	total: 73.3ms	remaining: 1m 13s
# 1:	learn: 31.6983334	total: 91.6ms	remaining: 45.7s
# 2:	learn: 30.5833273	total: 111ms	remaining: 36.8s
# 3:	learn: 29.5147468	total: 129ms	remaining: 32.2s
# 4:	learn: 28.5525952	total: 148ms	remaining: 29.4s
# 5:	learn: 27.6334746	total: 174ms	remaining: 28.8s
# 6:	learn: 26.7772731	total: 201ms	remaining: 28.6s
# 7:	learn: 25.9933962	total: 224ms	remaining: 27.8s
# 8:	learn: 25.3138427	total: 248ms	remaining: 27.3s
# 9:	learn: 24.6846390	total: 273ms	remaining: 27s
# 10:	learn: 24.0696899	total: 294ms	remaining: 26.4s
# ...

# %%
acu_data
# Out:
#                      Name          RMSE            R2           MAE  \
# 0  GradientBoostRegressor  1.211325e+01  8.770419e-01  7.744536e+00
# 1              ElasticNet  3.454650e+01 -1.014129e-04  2.944331e+01
# 2                LightGBM  1.179314e+01  8.834546e-01  7.530351e+00
# 3            SGDRegressor  6.530468e+16 -3.573753e+30  5.075457e+16
# 4                CatBoost  1.145858e+01  8.899734e-01  7.149985e+00
# 5            kernal Ridge  3.960898e+01 -3.146897e-01  3.553333e+01
# 6       Linear Regression  1.916455e+01  6.922250e-01  1.470786e+01
# 7    Support Vector Ratio  2.376872e+01  5.265792e-01  1.745765e+01
# 8            XGBRegressor  1.171729e+01  8.849491e-01  7.169678e+00
# 9           BayesianRidge  1.915884e+01  6.924086e-01  1.470827e+01
#
#             MSE          MAEA
# 0  1.467307e+02  7.744536e+00
# 1  1.193461e+03  2.944331e+01
# 2  1.390783e+02  7.530351e+00
# 3  4.264702e+33  5.075457e+16
# 4  1.312992e+02  7.149985e+00
# 5  1.568872e+03  3.553333e+01
# ...

# %%
# Hyperparameter Optimization
xgb_parms={"max_depth":[3,4,5,6,10,12,15],
          "learning_rate":[0.05,0.10,0.15,0.20,0.25,0.30],
          #"min_samples_split":[1,3,5,7],
          "gamma":[0.0,0.1,0.2,0.3,0.4],
          "colsample_bytree":[0.3,0.4,0.5,0.6]}


rf_parms={"n_estimators": np.arange(100,1500,100),
         "max_depth": np.arange(1,20),
          
         "max_features":['auto','sqrt','log2']}

# %%
from sklearn.tree import DecisionTreeRegressor
from  sklearn.ensemble import RandomForestRegressor

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# Decision Tree sklearn
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~

model_11 = DecisionTreeRegressor()

model_11.fit(X_train, Y_train)

model_11_pred = model_11.predict(X_Val)

mean_abs_error_m11 = mean_absolute_error(model_11_pred, Y_Val)

print("Mean Absolute Error of Model 11 : ", mean_abs_error_m11)
# Out:
# Mean Absolute Error of Model 11 :  7.384102441160977

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# Random Forest sklearn
# ~~~~~~~~~~~~~~~~~~~~~~~~~

model_12 = RandomForestRegressor()

model_12.fit(X_train, Y_train.values.ravel())

model_12_pred = model_12.predict(X_Val)

mean_abs_error_m12 = mean_absolute_error(model_12_pred, Y_Val)

print("Mean Absolute Error of Model 12 : ", mean_abs_error_m12)
# Out:
# Mean Absolute Error of Model 12 :  6.48129407714451

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_search_rf = RandomizedSearchCV(model_12, param_distributions = rf_parms, n_iter = 5, scoring = 'roc_auc', n_jobs=-1, 
                                  cv = 5, verbose = 3)

# %%
# Hyperparameter Optimization
start_time = time.time()

random_search_rf.fit(X_train, Y_train.values.ravel())

end_time = time.time()

print("Time taken : {0}".format(end_time - start_time))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Time taken : 1523.069235086441

# %%
random_search_rf.best_estimator_
# Out:
# RandomForestRegressor(max_depth=18, n_estimators=1000)

# %%
 model_13 = RandomForestRegressor(max_depth=18, max_features='sqrt', n_estimators=1000)

# %%
model_13.fit(X_train, Y_train.values.ravel())

model_13_pred = model_13.predict(X_Val)

mean_abs_error_m13 = mean_absolute_error(model_13_pred, Y_Val)

print("Mean Absolute Error of Model 13 : ", mean_abs_error_m13)
# Out:
# Mean Absolute Error of Model 13 :  6.874662317474784

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# XGB Regressor sklearn
# ~~~~~~~~~~~~~~~~~~~~~~~~~

model_8 = XGBRegressor()

model_8.fit(X_train, Y_train)

model_8_pred = model_8.predict(X_Val)

mean_abs_error_m8 = mean_absolute_error(model_8_pred, Y_Val)

print("Mean Absolute Error of Model 8 : ", mean_abs_error_m8)
# Out:
# Mean Absolute Error of Model 8 :  7.169678204052809

# %%
random_search = RandomizedSearchCV(model_8, param_distributions = xgb_parms, n_iter = 5, n_jobs=-1, 
                                   cv = 5, verbose = 3)

# %%
start_time = time.time()

random_search.fit(X_train, Y_train)

end_time = time.time()

print("Time taken : {0}".format(end_time - start_time))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Time taken : 207.86626410484314

# %%
random_search.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.6,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0.1, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.1, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
random_search.best_params_
# Out:
# {'max_depth': 12, 'learning_rate': 0.1, 'gamma': 0.1, 'colsample_bytree': 0.6}

# %%
model_14 = XGBRegressor(**random_search.best_params_)

# %%
model_14.fit(X_train, Y_train)

model_14_pred = model_14.predict(X_Val)

mean_abs_error_m14 = mean_absolute_error(model_14_pred, Y_Val)

print("Mean Absolute Error of Model 14: ", mean_abs_error_m14)
# Out:
# Mean Absolute Error of Model 14:  6.397199640709845

# %% [markdown]
# ### WITHOUT OUTLIER

# %%
 #treatment of the outlier
from scipy import stats
import numpy as np
train1=train.copy()
print("shape of data before outliers :",train1.shape)
# using z score to remove the outier
z=np.abs(stats.zscore(train))
W_train=train[(z<3).all(axis=1)]
print("shape of data after outlier:",W_train.shape)


W_train.reset_index(inplace=True)
# Out:
# shape of data before outliers : (14700, 46)
# shape of data after outlier: (11163, 46)

# %%
X=W_train.iloc[:,0: -1]
Y =W_train.iloc[:, -1]
test_size=0.20
seed=42
X_Wtrain, X_Wval, Y_Wtrain, Y_Wval = train_test_split(X, Y, test_size=test_size,random_state=seed)

# %%
def Models(model, name, d):
    print("Working on {} model".format(name))
    
    
    cla = model
    cla.fit(X_Wtrain, Y_Wtrain)
    
   
    
    predW = cla.predict(X_Wval)
   
    
    MAE=mean_absolute_error(Y_Wval,predW)
    MSE=mean_squared_error(Y_Wval,predW)
    RMSE=mean_squared_error(Y_Wval,predW,squared=False)
    MAEA=mean_absolute_error(Y_Wval,predW)
    R2=r2_score(Y_Wval,predW)
    
    
    
    d['Name'].append(name)
    #d['Training ACU'].append(tr_auc)
    #d['Testing ACU'].append(te_auc)
    d["RMSE"].append(RMSE)
    d['MAE'].append(MAE)
    d['MSE'].append(MSE)
    d['MAEA'].append(MAEA)
    d['R2'].append(R2)
    
    
    
    
    print("**********"*5)
    print()
    return d

# %%
d = {'Name' : [], 'RMSE': [], 'R2': [], 'MAE': [], 'MSE': [],'MAEA': []}


models = [ [GradientBoostingRegressor(loss="squared_error",learning_rate=0.2,n_estimators=1000), 'GradientBoostRegressor'],
          [ElasticNet(max_iter=2000,normalize=True), 'ElasticNet'], 
          [LGBMRegressor(), 'LightGBM'],
          [SGDRegressor(l1_ratio=0.5,), "SGDRegressor"],

          [CatBoostRegressor(), 'CatBoost'], 
          [KernelRidge(alpha=1.0), 'kernal Ridge'],
          [LinearRegression(), 'Linear Regression'], 
          [SVR(C=1.0,epsilon=0.2), 'Support Vector Ratio' ],
         [XGBRegressor(objective="reg:linear"),"XGBRegressor"],
         [BayesianRidge(),"BayesianRidge"]
         ]




for model in models:
    d = Models(model[0], model[1], d)

acu_dataW = pd.DataFrame(data = d)
# Out:
# Working on GradientBoostRegressor model
# **************************************************
#
# Working on ElasticNet model
# **************************************************
#
# Working on LightGBM model
# **************************************************
#
# Working on SGDRegressor model
# **************************************************
#
# Working on CatBoost model
# Learning rate set to 0.057865
# 0:	learn: 33.5870657	total: 22ms	remaining: 22s
# 1:	learn: 32.3607095	total: 41.6ms	remaining: 20.7s
# 2:	learn: 31.3206027	total: 62.1ms	remaining: 20.6s
# 3:	learn: 30.3060443	total: 81.7ms	remaining: 20.3s
# 4:	learn: 29.3798070	total: 103ms	remaining: 20.5s
# 5:	learn: 28.5074057	total: 124ms	remaining: 20.6s
# 6:	learn: 27.7308543	total: 150ms	remaining: 21.3s
# 7:	learn: 26.9586987	total: 173ms	remaining: 21.4s
# 8:	learn: 26.1868251	total: 195ms	remaining: 21.5s
# 9:	learn: 25.4496233	total: 216ms	remaining: 21.4s
# 10:	learn: 24.8653972	total: 237ms	remaining: 21.3s
# ...

# %%
acu_dataW
# Out:
#                      Name          RMSE            R2           MAE  \
# 0  GradientBoostRegressor  1.281773e+01  8.590667e-01  8.399167e+00
# 1              ElasticNet  3.414713e+01 -2.298290e-04  3.000642e+01
# 2                LightGBM  1.247237e+01  8.665589e-01  8.142651e+00
# 3            SGDRegressor  3.361586e+15 -9.693478e+27  2.481610e+15
# 4                CatBoost  1.205786e+01  8.752812e-01  7.765926e+00
# 5            kernal Ridge  2.554941e+01  4.400453e-01  2.053828e+01
# 6       Linear Regression  1.922613e+01  6.829155e-01  1.494102e+01
# 7    Support Vector Ratio  2.448739e+01  4.856292e-01  1.907642e+01
# 8            XGBRegressor  1.251385e+01  8.656700e-01  8.026464e+00
# 9           BayesianRidge  1.922302e+01  6.830179e-01  1.494078e+01
#
#             MSE          MAEA
# 0  1.642943e+02  8.399167e+00
# 1  1.166027e+03  3.000642e+01
# 2  1.555601e+02  8.142651e+00
# 3  1.130026e+31  2.481610e+15
# 4  1.453920e+02  7.765926e+00
# 5  6.527722e+02  2.053828e+01
# ...

# %%
model_11W = DecisionTreeRegressor()

model_11W.fit(X_Wtrain, Y_Wtrain)

model_11W_pred = model_11W.predict(X_Wval)

mean_abs_error_m11W = mean_absolute_error(model_11W_pred, Y_Wval)

print("Mean Absolute Error of Model 11 without Outliers : ", mean_abs_error_m11W)
# Out:
# Mean Absolute Error of Model 11 without Outliers :  8.980438871473353

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# Random Forest sklearn
# ~~~~~~~~~~~~~~~~~~~~~~~~~

model_12W = RandomForestRegressor()

model_12W.fit(X_Wtrain, Y_Wtrain.values.ravel())

model_12W_pred = model_12W.predict(X_Wval)

mean_abs_error_m12W = mean_absolute_error(model_12W_pred, Y_Wval)

print("Mean Absolute Error of Model 12 without Outliers : ", mean_abs_error_m12W)
# Out:
# Mean Absolute Error of Model 12 without Outliers :  7.372010073891626

# %%
random_search_rf = RandomizedSearchCV(model_12W, param_distributions = rf_parms, n_iter = 5, scoring = 'roc_auc', n_jobs=-1, 
                                  cv = 5, verbose = 3)

# %%
# Hyperparameter Optimization for without outlier
start_time = time.time()

random_search_rf.fit(X_Wtrain, Y_Wtrain.values.ravel())

end_time = time.time()

print("Time taken for without Outlier : {0}".format(end_time - start_time))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Time taken for without Outlier : 285.0724492073059

# %%
random_search_rf.best_estimator_
# Out:
# RandomForestRegressor(max_depth=9, max_features='sqrt', n_estimators=1200)

# %%
 model_13W = RandomForestRegressor(max_depth=9, max_features='sqrt', n_estimators=1200)

# %%
model_13W.fit(X_Wtrain, Y_Wtrain.values.ravel())

model_13W_pred = model_13W.predict(X_Wval)

mean_abs_error_m13W = mean_absolute_error(model_13W_pred, Y_Wval)

print("Mean Absolute Error of Model 13 without Outlier : ", mean_abs_error_m13W)
# Out:
# Mean Absolute Error of Model 13 without Outlier :  10.78033086865653

# %%
# ~~~~~~~~~~~~~~~~~~~~~~~~~
# XGB Regressor sklearn
# ~~~~~~~~~~~~~~~~~~~~~~~~~

model_8W = XGBRegressor()

model_8W.fit(X_Wtrain, Y_Wtrain)

model_8W_pred = model_8W.predict(X_Wval)

mean_abs_error_m8W = mean_absolute_error(model_8W_pred, Y_Wval)

print("Mean Absolute Error of Model 8 without Outliers : ", mean_abs_error_m8W)
# Out:
# Mean Absolute Error of Model 8 without Outliers :  8.0264635324903

# %%
random_search = RandomizedSearchCV(model_8W, param_distributions = xgb_parms, n_iter = 5, n_jobs=-1, 
                                   cv = 5, verbose = 3)

# %%
start_time = time.time()

random_search.fit(X_Wtrain, Y_Wtrain)

end_time = time.time()

print("Time taken : {0}".format(end_time - start_time))
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# Time taken : 92.53369140625

# %%
random_search.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=0.6,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0.3, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.2, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=12, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
random_search.best_params_
# Out:
# {'max_depth': 12, 'learning_rate': 0.2, 'gamma': 0.3, 'colsample_bytree': 0.6}

# %%
model_14W = XGBRegressor(**random_search.best_params_)

# %%
model_14W.fit(X_Wtrain, Y_Wtrain)

model_14W_pred = model_14W.predict(X_Wval)

mean_abs_error_m14W = mean_absolute_error(model_14W_pred, Y_Wval)

print("Mean Absolute Error of Model 14 without Outliers: ", mean_abs_error_m14W)
# Out:
# Mean Absolute Error of Model 14 without Outliers:  7.46239740635788

# %% [markdown]
# __Minimum Mean Absolute Error -   6.397199640709845 (XGB with hyperparameter optimization with Outlier)__

# %% [markdown]
# # Recall

# %%
# make predictions on test set for 
X_test=test.values

output_prediction=model_14.predict(X_test)

# %%
#to check the equality
print(len(output_prediction),len(X_test))
# Out:
# 6300 6300

# %%
import os
data_dir="C:/Users/Dell/Documents/Topcooder/challenge_dataset"
solution_df = pd.read_csv(os.path.join(data_dir, "test_x.csv"),header=None)
solution_df['target'] = output_prediction
solution_df.to_csv('solution.csv', index=False)
